# %% [markdown]
# <a href="https://colab.research.google.com/github/lavanyagokul0809/pylance-release/blob/main/lavanya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{
  "nbformat": 4,
  "nbformat_minor": 0,
  "metadata": {
    "colab": {
      "provenance": [],
      "collapsed_sections": []
    },
    "kernelspec": {
      "name": "python3",
      "display_name": "Python 3"
    },
    "language_info": {
      "name": "python"
    }
  },
  "cells": [
    {
      "cell_type": "code",
      "execution_count": 1,
      "metadata": {
        "id": "z1hGeSTG8hsr"
      },
      "outputs": [],
      "source": [
        "import numpy as np\n",
        "import pandas as pd"
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "df = pd.read_csv(\"/content/Churn_Modelling.csv\")"
      ],
      "metadata": {
        "id": "k8PIAfPN88Ql"
      },
      "execution_count": 2,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "df.shape"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "F-lmqBV59BFO",
        "outputId": "4adc7411-dfa9-4640-dd47-5c228670f12a"
      },
      "execution_count": 3,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "(10000, 14)"
            ]
          },
          "metadata": {},
          "execution_count": 3
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "df.head()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 270
        },
        "id": "p3CnQqUy9FB5",
        "outputId": "b16ac48b-eaa1-4c34-e549-68a46cb4804a"
      },
      "execution_count": 4,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "   RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \\\n",
              "0          1    15634602  Hargrave          619    France  Female   42   \n",
              "1          2    15647311      Hill          608     Spain  Female   41   \n",
              "2          3    15619304      Onio          502    France  Female   42   \n",
              "3          4    15701354      Boni          699    France  Female   39   \n",
              "4          5    15737888  Mitchell          850     Spain  Female   43   \n",
              "\n",
              "   Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \\\n",
              "0       2       0.00              1          1               1   \n",
              "1       1   83807.86              1          0               1   \n",
              "2       8  159660.80              3          1               0   \n",
              "3       1       0.00              2          0               0   \n",
              "4       2  125510.82              1          1               1   \n",
              "\n",
              "   EstimatedSalary  Exited  \n",
              "0        101348.88       1  \n",
              "1        112542.58       0  \n",
              "2        113931.57       1  \n",
              "3         93826.63       0  \n",
              "4         79084.10       0  "
            ],
            "text/html": [
              "\n",
              "  <div id=\"df-ed8c1e58-c02a-4a9d-bdc9-7b0392bd6daa\">\n",
              "    <div class=\"colab-df-container\">\n",
              "      <div>\n",
              "<style scoped>\n",
              "    .dataframe tbody tr th:only-of-type {\n",
              "        vertical-align: middle;\n",
              "    }\n",
              "\n",
              "    .dataframe tbody tr th {\n",
              "        vertical-align: top;\n",
              "    }\n",
              "\n",
              "    .dataframe thead th {\n",
              "        text-align: right;\n",
              "    }\n",
              "</style>\n",
              "<table border=\"1\" class=\"dataframe\">\n",
              "  <thead>\n",
              "    <tr style=\"text-align: right;\">\n",
              "      <th></th>\n",
              "      <th>RowNumber</th>\n",
              "      <th>CustomerId</th>\n",
              "      <th>Surname</th>\n",
              "      <th>CreditScore</th>\n",
              "      <th>Geography</th>\n",
              "      <th>Gender</th>\n",
              "      <th>Age</th>\n",
              "      <th>Tenure</th>\n",
              "      <th>Balance</th>\n",
              "      <th>NumOfProducts</th>\n",
              "      <th>HasCrCard</th>\n",
              "      <th>IsActiveMember</th>\n",
              "      <th>EstimatedSalary</th>\n",
              "      <th>Exited</th>\n",
              "    </tr>\n",
              "  </thead>\n",
              "  <tbody>\n",
              "    <tr>\n",
              "      <th>0</th>\n",
              "      <td>1</td>\n",
              "      <td>15634602</td>\n",
              "      <td>Hargrave</td>\n",
              "      <td>619</td>\n",
              "      <td>France</td>\n",
              "      <td>Female</td>\n",
              "      <td>42</td>\n",
              "      <td>2</td>\n",
              "      <td>0.00</td>\n",
              "      <td>1</td>\n",
              "      <td>1</td>\n",
              "      <td>1</td>\n",
              "      <td>101348.88</td>\n",
              "      <td>1</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>1</th>\n",
              "      <td>2</td>\n",
              "      <td>15647311</td>\n",
              "      <td>Hill</td>\n",
              "      <td>608</td>\n",
              "      <td>Spain</td>\n",
              "      <td>Female</td>\n",
              "      <td>41</td>\n",
              "      <td>1</td>\n",
              "      <td>83807.86</td>\n",
              "      <td>1</td>\n",
              "      <td>0</td>\n",
              "      <td>1</td>\n",
              "      <td>112542.58</td>\n",
              "      <td>0</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>2</th>\n",
              "      <td>3</td>\n",
              "      <td>15619304</td>\n",
              "      <td>Onio</td>\n",
              "      <td>502</td>\n",
              "      <td>France</td>\n",
              "      <td>Female</td>\n",
              "      <td>42</td>\n",
              "      <td>8</td>\n",
              "      <td>159660.80</td>\n",
              "      <td>3</td>\n",
              "      <td>1</td>\n",
              "      <td>0</td>\n",
              "      <td>113931.57</td>\n",
              "      <td>1</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>3</th>\n",
              "      <td>4</td>\n",
              "      <td>15701354</td>\n",
              "      <td>Boni</td>\n",
              "      <td>699</td>\n",
              "      <td>France</td>\n",
              "      <td>Female</td>\n",
              "      <td>39</td>\n",
              "      <td>1</td>\n",
              "      <td>0.00</td>\n",
              "      <td>2</td>\n",
              "      <td>0</td>\n",
              "      <td>0</td>\n",
              "      <td>93826.63</td>\n",
              "      <td>0</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>4</th>\n",
              "      <td>5</td>\n",
              "      <td>15737888</td>\n",
              "      <td>Mitchell</td>\n",
              "      <td>850</td>\n",
              "      <td>Spain</td>\n",
              "      <td>Female</td>\n",
              "      <td>43</td>\n",
              "      <td>2</td>\n",
              "      <td>125510.82</td>\n",
              "      <td>1</td>\n",
              "      <td>1</td>\n",
              "      <td>1</td>\n",
              "      <td>79084.10</td>\n",
              "      <td>0</td>\n",
              "    </tr>\n",
              "  </tbody>\n",
              "</table>\n",
              "</div>\n",
              "      <button class=\"colab-df-convert\" onclick=\"convertToInteractive('df-ed8c1e58-c02a-4a9d-bdc9-7b0392bd6daa')\"\n",
              "              title=\"Convert this dataframe to an interactive table.\"\n",
              "              style=\"display:none;\">\n",
              "        \n",
              "  <svg xmlns=\"http://www.w3.org/2000/svg\" height=\"24px\"viewBox=\"0 0 24 24\"\n",
              "       width=\"24px\">\n",
              "    <path d=\"M0 0h24v24H0V0z\" fill=\"none\"/>\n",
              "    <path d=\"M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z\"/><path d=\"M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z\"/>\n",
              "  </svg>\n",
              "      </button>\n",
              "      \n",
              "  <style>\n",
              "    .colab-df-container {\n",
              "      display:flex;\n",
              "      flex-wrap:wrap;\n",
              "      gap: 12px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert {\n",
              "      background-color: #E8F0FE;\n",
              "      border: none;\n",
              "      border-radius: 50%;\n",
              "      cursor: pointer;\n",
              "      display: none;\n",
              "      fill: #1967D2;\n",
              "      height: 32px;\n",
              "      padding: 0 0 0 0;\n",
              "      width: 32px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert:hover {\n",
              "      background-color: #E2EBFA;\n",
              "      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n",
              "      fill: #174EA6;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert {\n",
              "      background-color: #3B4455;\n",
              "      fill: #D2E3FC;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert:hover {\n",
              "      background-color: #434B5C;\n",
              "      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n",
              "      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n",
              "      fill: #FFFFFF;\n",
              "    }\n",
              "  </style>\n",
              "\n",
              "      <script>\n",
              "        const buttonEl =\n",
              "          document.querySelector('#df-ed8c1e58-c02a-4a9d-bdc9-7b0392bd6daa button.colab-df-convert');\n",
              "        buttonEl.style.display =\n",
              "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
              "\n",
              "        async function convertToInteractive(key) {\n",
              "          const element = document.querySelector('#df-ed8c1e58-c02a-4a9d-bdc9-7b0392bd6daa');\n",
              "          const dataTable =\n",
              "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
              "                                                     [key], {});\n",
              "          if (!dataTable) return;\n",
              "\n",
              "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
              "            '<a target=\"_blank\" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'\n",
              "            + ' to learn more about interactive tables.';\n",
              "          element.innerHTML = '';\n",
              "          dataTable['output_type'] = 'display_data';\n",
              "          await google.colab.output.renderOutput(dataTable, element);\n",
              "          const docLink = document.createElement('div');\n",
              "          docLink.innerHTML = docLinkHtml;\n",
              "          element.appendChild(docLink);\n",
              "        }\n",
              "      </script>\n",
              "    </div>\n",
              "  </div>\n",
              "  "
            ]
          },
          "metadata": {},
          "execution_count": 4
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "df.groupby(['Geography']).count()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 239
        },
        "id": "zSPPGqAn9Z-z",
        "outputId": "794dfc41-bbfd-41b6-f350-1155fdc3fc82"
      },
      "execution_count": 5,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "           RowNumber  CustomerId  Surname  CreditScore  Gender   Age  Tenure  \\\n",
              "Geography                                                                      \n",
              "France          5014        5014     5014         5014    5014  5014    5014   \n",
              "Germany         2509        2509     2509         2509    2509  2509    2509   \n",
              "Spain           2477        2477     2477         2477    2477  2477    2477   \n",
              "\n",
              "           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \\\n",
              "Geography                                                                       \n",
              "France        5014           5014       5014            5014             5014   \n",
              "Germany       2509           2509       2509            2509             2509   \n",
              "Spain         2477           2477       2477            2477             2477   \n",
              "\n",
              "           Exited  \n",
              "Geography          \n",
              "France       5014  \n",
              "Germany      2509  \n",
              "Spain        2477  "
            ],
            "text/html": [
              "\n",
              "  <div id=\"df-a16eea86-dd25-4d83-9774-8d9243de3932\">\n",
              "    <div class=\"colab-df-container\">\n",
              "      <div>\n",
              "<style scoped>\n",
              "    .dataframe tbody tr th:only-of-type {\n",
              "        vertical-align: middle;\n",
              "    }\n",
              "\n",
              "    .dataframe tbody tr th {\n",
              "        vertical-align: top;\n",
              "    }\n",
              "\n",
              "    .dataframe thead th {\n",
              "        text-align: right;\n",
              "    }\n",
              "</style>\n",
              "<table border=\"1\" class=\"dataframe\">\n",
              "  <thead>\n",
              "    <tr style=\"text-align: right;\">\n",
              "      <th></th>\n",
              "      <th>RowNumber</th>\n",
              "      <th>CustomerId</th>\n",
              "      <th>Surname</th>\n",
              "      <th>CreditScore</th>\n",
              "      <th>Gender</th>\n",
              "      <th>Age</th>\n",
              "      <th>Tenure</th>\n",
              "      <th>Balance</th>\n",
              "      <th>NumOfProducts</th>\n",
              "      <th>HasCrCard</th>\n",
              "      <th>IsActiveMember</th>\n",
              "      <th>EstimatedSalary</th>\n",
              "      <th>Exited</th>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>Geography</th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "    </tr>\n",
              "  </thead>\n",
              "  <tbody>\n",
              "    <tr>\n",
              "      <th>France</th>\n",
              "      <td>5014</td>\n",
              "      <td>5014</td>\n",
              "      <td>5014</td>\n",
              "      <td>5014</td>\n",
              "      <td>5014</td>\n",
              "      <td>5014</td>\n",
              "      <td>5014</td>\n",
              "      <td>5014</td>\n",
              "      <td>5014</td>\n",
              "      <td>5014</td>\n",
              "      <td>5014</td>\n",
              "      <td>5014</td>\n",
              "      <td>5014</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>Germany</th>\n",
              "      <td>2509</td>\n",
              "      <td>2509</td>\n",
              "      <td>2509</td>\n",
              "      <td>2509</td>\n",
              "      <td>2509</td>\n",
              "      <td>2509</td>\n",
              "      <td>2509</td>\n",
              "      <td>2509</td>\n",
              "      <td>2509</td>\n",
              "      <td>2509</td>\n",
              "      <td>2509</td>\n",
              "      <td>2509</td>\n",
              "      <td>2509</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>Spain</th>\n",
              "      <td>2477</td>\n",
              "      <td>2477</td>\n",
              "      <td>2477</td>\n",
              "      <td>2477</td>\n",
              "      <td>2477</td>\n",
              "      <td>2477</td>\n",
              "      <td>2477</td>\n",
              "      <td>2477</td>\n",
              "      <td>2477</td>\n",
              "      <td>2477</td>\n",
              "      <td>2477</td>\n",
              "      <td>2477</td>\n",
              "      <td>2477</td>\n",
              "    </tr>\n",
              "  </tbody>\n",
              "</table>\n",
              "</div>\n",
              "      <button class=\"colab-df-convert\" onclick=\"convertToInteractive('df-a16eea86-dd25-4d83-9774-8d9243de3932')\"\n",
              "              title=\"Convert this dataframe to an interactive table.\"\n",
              "              style=\"display:none;\">\n",
              "        \n",
              "  <svg xmlns=\"http://www.w3.org/2000/svg\" height=\"24px\"viewBox=\"0 0 24 24\"\n",
              "       width=\"24px\">\n",
              "    <path d=\"M0 0h24v24H0V0z\" fill=\"none\"/>\n",
              "    <path d=\"M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z\"/><path d=\"M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z\"/>\n",
              "  </svg>\n",
              "      </button>\n",
              "      \n",
              "  <style>\n",
              "    .colab-df-container {\n",
              "      display:flex;\n",
              "      flex-wrap:wrap;\n",
              "      gap: 12px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert {\n",
              "      background-color: #E8F0FE;\n",
              "      border: none;\n",
              "      border-radius: 50%;\n",
              "      cursor: pointer;\n",
              "      display: none;\n",
              "      fill: #1967D2;\n",
              "      height: 32px;\n",
              "      padding: 0 0 0 0;\n",
              "      width: 32px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert:hover {\n",
              "      background-color: #E2EBFA;\n",
              "      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n",
              "      fill: #174EA6;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert {\n",
              "      background-color: #3B4455;\n",
              "      fill: #D2E3FC;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert:hover {\n",
              "      background-color: #434B5C;\n",
              "      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n",
              "      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n",
              "      fill: #FFFFFF;\n",
              "    }\n",
              "  </style>\n",
              "\n",
              "      <script>\n",
              "        const buttonEl =\n",
              "          document.querySelector('#df-a16eea86-dd25-4d83-9774-8d9243de3932 button.colab-df-convert');\n",
              "        buttonEl.style.display =\n",
              "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
              "\n",
              "        async function convertToInteractive(key) {\n",
              "          const element = document.querySelector('#df-a16eea86-dd25-4d83-9774-8d9243de3932');\n",
              "          const dataTable =\n",
              "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
              "                                                     [key], {});\n",
              "          if (!dataTable) return;\n",
              "\n",
              "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
              "            '<a target=\"_blank\" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'\n",
              "            + ' to learn more about interactive tables.';\n",
              "          element.innerHTML = '';\n",
              "          dataTable['output_type'] = 'display_data';\n",
              "          await google.colab.output.renderOutput(dataTable, element);\n",
              "          const docLink = document.createElement('div');\n",
              "          docLink.innerHTML = docLinkHtml;\n",
              "          element.appendChild(docLink);\n",
              "        }\n",
              "      </script>\n",
              "    </div>\n",
              "  </div>\n",
              "  "
            ]
          },
          "metadata": {},
          "execution_count": 5
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "df.groupby(['Gender']).count()\n"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 207
        },
        "id": "dC3rEENL-7EJ",
        "outputId": "55683982-8beb-404c-e897-ce3f2249c806"
      },
      "execution_count": 6,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "        RowNumber  CustomerId  Surname  CreditScore  Geography   Age  Tenure  \\\n",
              "Gender                                                                         \n",
              "Female       4543        4543     4543         4543       4543  4543    4543   \n",
              "Male         5457        5457     5457         5457       5457  5457    5457   \n",
              "\n",
              "        Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \\\n",
              "Gender                                                                       \n",
              "Female     4543           4543       4543            4543             4543   \n",
              "Male       5457           5457       5457            5457             5457   \n",
              "\n",
              "        Exited  \n",
              "Gender          \n",
              "Female    4543  \n",
              "Male      5457  "
            ],
            "text/html": [
              "\n",
              "  <div id=\"df-adb81ed6-b9c9-4de1-a480-a997d97cb36e\">\n",
              "    <div class=\"colab-df-container\">\n",
              "      <div>\n",
              "<style scoped>\n",
              "    .dataframe tbody tr th:only-of-type {\n",
              "        vertical-align: middle;\n",
              "    }\n",
              "\n",
              "    .dataframe tbody tr th {\n",
              "        vertical-align: top;\n",
              "    }\n",
              "\n",
              "    .dataframe thead th {\n",
              "        text-align: right;\n",
              "    }\n",
              "</style>\n",
              "<table border=\"1\" class=\"dataframe\">\n",
              "  <thead>\n",
              "    <tr style=\"text-align: right;\">\n",
              "      <th></th>\n",
              "      <th>RowNumber</th>\n",
              "      <th>CustomerId</th>\n",
              "      <th>Surname</th>\n",
              "      <th>CreditScore</th>\n",
              "      <th>Geography</th>\n",
              "      <th>Age</th>\n",
              "      <th>Tenure</th>\n",
              "      <th>Balance</th>\n",
              "      <th>NumOfProducts</th>\n",
              "      <th>HasCrCard</th>\n",
              "      <th>IsActiveMember</th>\n",
              "      <th>EstimatedSalary</th>\n",
              "      <th>Exited</th>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>Gender</th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "      <th></th>\n",
              "    </tr>\n",
              "  </thead>\n",
              "  <tbody>\n",
              "    <tr>\n",
              "      <th>Female</th>\n",
              "      <td>4543</td>\n",
              "      <td>4543</td>\n",
              "      <td>4543</td>\n",
              "      <td>4543</td>\n",
              "      <td>4543</td>\n",
              "      <td>4543</td>\n",
              "      <td>4543</td>\n",
              "      <td>4543</td>\n",
              "      <td>4543</td>\n",
              "      <td>4543</td>\n",
              "      <td>4543</td>\n",
              "      <td>4543</td>\n",
              "      <td>4543</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>Male</th>\n",
              "      <td>5457</td>\n",
              "      <td>5457</td>\n",
              "      <td>5457</td>\n",
              "      <td>5457</td>\n",
              "      <td>5457</td>\n",
              "      <td>5457</td>\n",
              "      <td>5457</td>\n",
              "      <td>5457</td>\n",
              "      <td>5457</td>\n",
              "      <td>5457</td>\n",
              "      <td>5457</td>\n",
              "      <td>5457</td>\n",
              "      <td>5457</td>\n",
              "    </tr>\n",
              "  </tbody>\n",
              "</table>\n",
              "</div>\n",
              "      <button class=\"colab-df-convert\" onclick=\"convertToInteractive('df-adb81ed6-b9c9-4de1-a480-a997d97cb36e')\"\n",
              "              title=\"Convert this dataframe to an interactive table.\"\n",
              "              style=\"display:none;\">\n",
              "        \n",
              "  <svg xmlns=\"http://www.w3.org/2000/svg\" height=\"24px\"viewBox=\"0 0 24 24\"\n",
              "       width=\"24px\">\n",
              "    <path d=\"M0 0h24v24H0V0z\" fill=\"none\"/>\n",
              "    <path d=\"M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z\"/><path d=\"M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z\"/>\n",
              "  </svg>\n",
              "      </button>\n",
              "      \n",
              "  <style>\n",
              "    .colab-df-container {\n",
              "      display:flex;\n",
              "      flex-wrap:wrap;\n",
              "      gap: 12px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert {\n",
              "      background-color: #E8F0FE;\n",
              "      border: none;\n",
              "      border-radius: 50%;\n",
              "      cursor: pointer;\n",
              "      display: none;\n",
              "      fill: #1967D2;\n",
              "      height: 32px;\n",
              "      padding: 0 0 0 0;\n",
              "      width: 32px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert:hover {\n",
              "      background-color: #E2EBFA;\n",
              "      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n",
              "      fill: #174EA6;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert {\n",
              "      background-color: #3B4455;\n",
              "      fill: #D2E3FC;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert:hover {\n",
              "      background-color: #434B5C;\n",
              "      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n",
              "      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n",
              "      fill: #FFFFFF;\n",
              "    }\n",
              "  </style>\n",
              "\n",
              "      <script>\n",
              "        const buttonEl =\n",
              "          document.querySelector('#df-adb81ed6-b9c9-4de1-a480-a997d97cb36e button.colab-df-convert');\n",
              "        buttonEl.style.display =\n",
              "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
              "\n",
              "        async function convertToInteractive(key) {\n",
              "          const element = document.querySelector('#df-adb81ed6-b9c9-4de1-a480-a997d97cb36e');\n",
              "          const dataTable =\n",
              "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
              "                                                     [key], {});\n",
              "          if (!dataTable) return;\n",
              "\n",
              "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
              "            '<a target=\"_blank\" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'\n",
              "            + ' to learn more about interactive tables.';\n",
              "          element.innerHTML = '';\n",
              "          dataTable['output_type'] = 'display_data';\n",
              "          await google.colab.output.renderOutput(dataTable, element);\n",
              "          const docLink = document.createElement('div');\n",
              "          docLink.innerHTML = docLinkHtml;\n",
              "          element.appendChild(docLink);\n",
              "        }\n",
              "      </script>\n",
              "    </div>\n",
              "  </div>\n",
              "  "
            ]
          },
          "metadata": {},
          "execution_count": 6
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "freq_table = df.groupby(['Geography']).size().reset_index(name='Count').rename(columns={'Geography':'Geography'})\n",
        "freq_table"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 143
        },
        "id": "5pxroRhR_PEc",
        "outputId": "59778021-b256-42f8-9d66-86e20d78d557"
      },
      "execution_count": 8,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "  Geography  Count\n",
              "0    France   5014\n",
              "1   Germany   2509\n",
              "2     Spain   2477"
            ],
            "text/html": [
              "\n",
              "  <div id=\"df-cefd63f6-d890-4404-932b-412777a9992d\">\n",
              "    <div class=\"colab-df-container\">\n",
              "      <div>\n",
              "<style scoped>\n",
              "    .dataframe tbody tr th:only-of-type {\n",
              "        vertical-align: middle;\n",
              "    }\n",
              "\n",
              "    .dataframe tbody tr th {\n",
              "        vertical-align: top;\n",
              "    }\n",
              "\n",
              "    .dataframe thead th {\n",
              "        text-align: right;\n",
              "    }\n",
              "</style>\n",
              "<table border=\"1\" class=\"dataframe\">\n",
              "  <thead>\n",
              "    <tr style=\"text-align: right;\">\n",
              "      <th></th>\n",
              "      <th>Geography</th>\n",
              "      <th>Count</th>\n",
              "    </tr>\n",
              "  </thead>\n",
              "  <tbody>\n",
              "    <tr>\n",
              "      <th>0</th>\n",
              "      <td>France</td>\n",
              "      <td>5014</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>1</th>\n",
              "      <td>Germany</td>\n",
              "      <td>2509</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>2</th>\n",
              "      <td>Spain</td>\n",
              "      <td>2477</td>\n",
              "    </tr>\n",
              "  </tbody>\n",
              "</table>\n",
              "</div>\n",
              "      <button class=\"colab-df-convert\" onclick=\"convertToInteractive('df-cefd63f6-d890-4404-932b-412777a9992d')\"\n",
              "              title=\"Convert this dataframe to an interactive table.\"\n",
              "              style=\"display:none;\">\n",
              "        \n",
              "  <svg xmlns=\"http://www.w3.org/2000/svg\" height=\"24px\"viewBox=\"0 0 24 24\"\n",
              "       width=\"24px\">\n",
              "    <path d=\"M0 0h24v24H0V0z\" fill=\"none\"/>\n",
              "    <path d=\"M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z\"/><path d=\"M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z\"/>\n",
              "  </svg>\n",
              "      </button>\n",
              "      \n",
              "  <style>\n",
              "    .colab-df-container {\n",
              "      display:flex;\n",
              "      flex-wrap:wrap;\n",
              "      gap: 12px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert {\n",
              "      background-color: #E8F0FE;\n",
              "      border: none;\n",
              "      border-radius: 50%;\n",
              "      cursor: pointer;\n",
              "      display: none;\n",
              "      fill: #1967D2;\n",
              "      height: 32px;\n",
              "      padding: 0 0 0 0;\n",
              "      width: 32px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert:hover {\n",
              "      background-color: #E2EBFA;\n",
              "      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n",
              "      fill: #174EA6;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert {\n",
              "      background-color: #3B4455;\n",
              "      fill: #D2E3FC;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert:hover {\n",
              "      background-color: #434B5C;\n",
              "      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n",
              "      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n",
              "      fill: #FFFFFF;\n",
              "    }\n",
              "  </style>\n",
              "\n",
              "      <script>\n",
              "        const buttonEl =\n",
              "          document.querySelector('#df-cefd63f6-d890-4404-932b-412777a9992d button.colab-df-convert');\n",
              "        buttonEl.style.display =\n",
              "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
              "\n",
              "        async function convertToInteractive(key) {\n",
              "          const element = document.querySelector('#df-cefd63f6-d890-4404-932b-412777a9992d');\n",
              "          const dataTable =\n",
              "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
              "                                                     [key], {});\n",
              "          if (!dataTable) return;\n",
              "\n",
              "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
              "            '<a target=\"_blank\" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'\n",
              "            + ' to learn more about interactive tables.';\n",
              "          element.innerHTML = '';\n",
              "          dataTable['output_type'] = 'display_data';\n",
              "          await google.colab.output.renderOutput(dataTable, element);\n",
              "          const docLink = document.createElement('div');\n",
              "          docLink.innerHTML = docLinkHtml;\n",
              "          element.appendChild(docLink);\n",
              "        }\n",
              "      </script>\n",
              "    </div>\n",
              "  </div>\n",
              "  "
            ]
          },
          "metadata": {},
          "execution_count": 8
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "freq_table = df.groupby(['Gender']).size().reset_index(name='Count').rename(columns={'Gender':'Gender'})\n",
        "freq_table"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 112
        },
        "id": "m5wyAhMgAuwo",
        "outputId": "36c5cc5e-d5c3-42ee-9254-2927724c47e7"
      },
      "execution_count": 9,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "   Gender  Count\n",
              "0  Female   4543\n",
              "1    Male   5457"
            ],
            "text/html": [
              "\n",
              "  <div id=\"df-39ff7570-ab2b-4f33-b08e-db8f43ea3e99\">\n",
              "    <div class=\"colab-df-container\">\n",
              "      <div>\n",
              "<style scoped>\n",
              "    .dataframe tbody tr th:only-of-type {\n",
              "        vertical-align: middle;\n",
              "    }\n",
              "\n",
              "    .dataframe tbody tr th {\n",
              "        vertical-align: top;\n",
              "    }\n",
              "\n",
              "    .dataframe thead th {\n",
              "        text-align: right;\n",
              "    }\n",
              "</style>\n",
              "<table border=\"1\" class=\"dataframe\">\n",
              "  <thead>\n",
              "    <tr style=\"text-align: right;\">\n",
              "      <th></th>\n",
              "      <th>Gender</th>\n",
              "      <th>Count</th>\n",
              "    </tr>\n",
              "  </thead>\n",
              "  <tbody>\n",
              "    <tr>\n",
              "      <th>0</th>\n",
              "      <td>Female</td>\n",
              "      <td>4543</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>1</th>\n",
              "      <td>Male</td>\n",
              "      <td>5457</td>\n",
              "    </tr>\n",
              "  </tbody>\n",
              "</table>\n",
              "</div>\n",
              "      <button class=\"colab-df-convert\" onclick=\"convertToInteractive('df-39ff7570-ab2b-4f33-b08e-db8f43ea3e99')\"\n",
              "              title=\"Convert this dataframe to an interactive table.\"\n",
              "              style=\"display:none;\">\n",
              "        \n",
              "  <svg xmlns=\"http://www.w3.org/2000/svg\" height=\"24px\"viewBox=\"0 0 24 24\"\n",
              "       width=\"24px\">\n",
              "    <path d=\"M0 0h24v24H0V0z\" fill=\"none\"/>\n",
              "    <path d=\"M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z\"/><path d=\"M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z\"/>\n",
              "  </svg>\n",
              "      </button>\n",
              "      \n",
              "  <style>\n",
              "    .colab-df-container {\n",
              "      display:flex;\n",
              "      flex-wrap:wrap;\n",
              "      gap: 12px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert {\n",
              "      background-color: #E8F0FE;\n",
              "      border: none;\n",
              "      border-radius: 50%;\n",
              "      cursor: pointer;\n",
              "      display: none;\n",
              "      fill: #1967D2;\n",
              "      height: 32px;\n",
              "      padding: 0 0 0 0;\n",
              "      width: 32px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert:hover {\n",
              "      background-color: #E2EBFA;\n",
              "      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n",
              "      fill: #174EA6;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert {\n",
              "      background-color: #3B4455;\n",
              "      fill: #D2E3FC;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert:hover {\n",
              "      background-color: #434B5C;\n",
              "      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n",
              "      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n",
              "      fill: #FFFFFF;\n",
              "    }\n",
              "  </style>\n",
              "\n",
              "      <script>\n",
              "        const buttonEl =\n",
              "          document.querySelector('#df-39ff7570-ab2b-4f33-b08e-db8f43ea3e99 button.colab-df-convert');\n",
              "        buttonEl.style.display =\n",
              "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
              "\n",
              "        async function convertToInteractive(key) {\n",
              "          const element = document.querySelector('#df-39ff7570-ab2b-4f33-b08e-db8f43ea3e99');\n",
              "          const dataTable =\n",
              "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
              "                                                     [key], {});\n",
              "          if (!dataTable) return;\n",
              "\n",
              "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
              "            '<a target=\"_blank\" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'\n",
              "            + ' to learn more about interactive tables.';\n",
              "          element.innerHTML = '';\n",
              "          dataTable['output_type'] = 'display_data';\n",
              "          await google.colab.output.renderOutput(dataTable, element);\n",
              "          const docLink = document.createElement('div');\n",
              "          docLink.innerHTML = docLinkHtml;\n",
              "          element.appendChild(docLink);\n",
              "        }\n",
              "      </script>\n",
              "    </div>\n",
              "  </div>\n",
              "  "
            ]
          },
          "metadata": {},
          "execution_count": 9
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "import matplotlib.pyplot as plt\n",
        "import seaborn as sns\n",
        "%matplotlib inline"
      ],
      "metadata": {
        "id": "XSfx6PSlBF1T"
      },
      "execution_count": 11,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "plt.bar(freq_table['Gender'], freq_table['Count'])\n",
        "plt.show()"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 265
        },
        "id": "5tT5acr8BTay",
        "outputId": "58c25e3c-cc07-421a-fd5d-86fff27a2381"
      },
      "execution_count": 14,
      "outputs": [
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 432x288 with 1 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "freq_table['Count%'] = freq_table['Count']/sum(freq_table['Count'])*100\n",
        "freq_table"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 112
        },
        "id": "Vh37rJrIDlEW",
        "outputId": "f91f3e0b-8c4d-4ddb-8f55-c196ef6221ed"
      },
      "execution_count": 16,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "   Gender  Count  Count%\n",
              "0  Female   4543   45.43\n",
              "1    Male   5457   54.57"
            ],
            "text/html": [
              "\n",
              "  <div id=\"df-6eb12a06-e931-43a7-bd6d-968ca7d06ed0\">\n",
              "    <div class=\"colab-df-container\">\n",
              "      <div>\n",
              "<style scoped>\n",
              "    .dataframe tbody tr th:only-of-type {\n",
              "        vertical-align: middle;\n",
              "    }\n",
              "\n",
              "    .dataframe tbody tr th {\n",
              "        vertical-align: top;\n",
              "    }\n",
              "\n",
              "    .dataframe thead th {\n",
              "        text-align: right;\n",
              "    }\n",
              "</style>\n",
              "<table border=\"1\" class=\"dataframe\">\n",
              "  <thead>\n",
              "    <tr style=\"text-align: right;\">\n",
              "      <th></th>\n",
              "      <th>Gender</th>\n",
              "      <th>Count</th>\n",
              "      <th>Count%</th>\n",
              "    </tr>\n",
              "  </thead>\n",
              "  <tbody>\n",
              "    <tr>\n",
              "      <th>0</th>\n",
              "      <td>Female</td>\n",
              "      <td>4543</td>\n",
              "      <td>45.43</td>\n",
              "    </tr>\n",
              "    <tr>\n",
              "      <th>1</th>\n",
              "      <td>Male</td>\n",
              "      <td>5457</td>\n",
              "      <td>54.57</td>\n",
              "    </tr>\n",
              "  </tbody>\n",
              "</table>\n",
              "</div>\n",
              "      <button class=\"colab-df-convert\" onclick=\"convertToInteractive('df-6eb12a06-e931-43a7-bd6d-968ca7d06ed0')\"\n",
              "              title=\"Convert this dataframe to an interactive table.\"\n",
              "              style=\"display:none;\">\n",
              "        \n",
              "  <svg xmlns=\"http://www.w3.org/2000/svg\" height=\"24px\"viewBox=\"0 0 24 24\"\n",
              "       width=\"24px\">\n",
              "    <path d=\"M0 0h24v24H0V0z\" fill=\"none\"/>\n",
              "    <path d=\"M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z\"/><path d=\"M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z\"/>\n",
              "  </svg>\n",
              "      </button>\n",
              "      \n",
              "  <style>\n",
              "    .colab-df-container {\n",
              "      display:flex;\n",
              "      flex-wrap:wrap;\n",
              "      gap: 12px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert {\n",
              "      background-color: #E8F0FE;\n",
              "      border: none;\n",
              "      border-radius: 50%;\n",
              "      cursor: pointer;\n",
              "      display: none;\n",
              "      fill: #1967D2;\n",
              "      height: 32px;\n",
              "      padding: 0 0 0 0;\n",
              "      width: 32px;\n",
              "    }\n",
              "\n",
              "    .colab-df-convert:hover {\n",
              "      background-color: #E2EBFA;\n",
              "      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n",
              "      fill: #174EA6;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert {\n",
              "      background-color: #3B4455;\n",
              "      fill: #D2E3FC;\n",
              "    }\n",
              "\n",
              "    [theme=dark] .colab-df-convert:hover {\n",
              "      background-color: #434B5C;\n",
              "      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n",
              "      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n",
              "      fill: #FFFFFF;\n",
              "    }\n",
              "  </style>\n",
              "\n",
              "      <script>\n",
              "        const buttonEl =\n",
              "          document.querySelector('#df-6eb12a06-e931-43a7-bd6d-968ca7d06ed0 button.colab-df-convert');\n",
              "        buttonEl.style.display =\n",
              "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
              "\n",
              "        async function convertToInteractive(key) {\n",
              "          const element = document.querySelector('#df-6eb12a06-e931-43a7-bd6d-968ca7d06ed0');\n",
              "          const dataTable =\n",
              "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
              "                                                     [key], {});\n",
              "          if (!dataTable) return;\n",
              "\n",
              "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
              "            '<a target=\"_blank\" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>'\n",
              "            + ' to learn more about interactive tables.';\n",
              "          element.innerHTML = '';\n",
              "          dataTable['output_type'] = 'display_data';\n",
              "          await google.colab.output.renderOutput(dataTable, element);\n",
              "          const docLink = document.createElement('div');\n",
              "          docLink.innerHTML = docLinkHtml;\n",
              "          element.appendChild(docLink);\n",
              "        }\n",
              "      </script>\n",
              "    </div>\n",
              "  </div>\n",
              "  "
            ]
          },
          "metadata": {},
          "execution_count": 16
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "#univariate analysis for Numerical datatypes\n",
        "df.select_dtypes(include=['int64','float64','Int64']).dtypes"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/"
        },
        "id": "ZdINrezEHmZB",
        "outputId": "662dc7a0-3692-4131-800d-4fe7094c4d5a"
      },
      "execution_count": 42,
      "outputs": [
        {
          "output_type": "execute_result",
          "data": {
            "text/plain": [
              "RowNumber            int64\n",
              "CustomerId           int64\n",
              "CreditScore          int64\n",
              "Age                  int64\n",
              "Tenure               int64\n",
              "Balance            float64\n",
              "NumOfProducts        int64\n",
              "HasCrCard            int64\n",
              "IsActiveMember       int64\n",
              "EstimatedSalary    float64\n",
              "Exited               int64\n",
              "dtype: object"
            ]
          },
          "metadata": {},
          "execution_count": 42
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "# seggregating variables into groups\n",
        "customer_details = ['CustomerId','Age','Tenure','CreditScore']\n",
        "employee = ['Balance','NumOfProducts','HasCrCard', 'IsActiveMember','EstimatedSalary','Exited']\n"
      ],
      "metadata": {
        "id": "E9cnRFBHIcGt"
      },
      "execution_count": 40,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "def UVA_numeric(df, var_group):\n",
        "  '''\n",
        "  Univariate_Analysis_numeric\n",
        "  takes a group of variables (INTEGER and FLOAT) and plot/print all the descriptives and properties along with KDE.\n",
        "\n",
        "  Runs a loop: calculate all the descriptives of i(th) variable and plot/print it\n",
        "  '''\n",
        "\n",
        "  size = len(var_group)\n",
        "  plt.figure(figsize = (7*size,3), dpi = 100)\n",
        "  \n",
        "  #looping for each variable\n",
        "  for j,i in enumerate(var_group):\n",
        "    \n",
        "    # calculating descriptives of variable\n",
        "    mini = df[i].min()\n",
        "    maxi = df[i].max()\n",
        "    ran =  df[i].max()-df[i].min()\n",
        "    mean = df[i].mean()\n",
        "    median =df[i].median()\n",
        "    st_dev = df[i].std()\n",
        "    skew = df[i].skew()\n",
        "    kurt = df[i].kurtosis()\n",
        "\n",
        "    # calculating points of standard deviation\n",
        "    points = mean-st_dev, mean+st_dev\n",
        "\n",
        "    #Plotting the variable with every information\n",
        "    plt.subplot(1,size,j+1)\n",
        "    sns.kdeplot(df[i], shade=True)\n",
        "    sns.lineplot(points, [0,0], color = 'black', label = \"std_dev\")\n",
        "    sns.scatterplot([mini,maxi], [0,0], color = 'orange', label = \"min/max\")\n",
        "    sns.scatterplot([mean], [0], color = 'red', label = \"mean\")\n",
        "    sns.scatterplot([median], [0], color = 'blue', label = \"median\")\n",
        "    plt.xlabel('{}'.format(i), fontsize = 20)\n",
        "    plt.ylabel('density')\n",
        "    plt.title('std_dev = {}; kurtosis = {};\\nskew = {}; range = {}\\nmean = {}; median = {}'.format((round(points[0],2),round(points[1],2)),\n",
        "    round(kurt,2),\n",
        "    round(skew,2),\n",
        "    (round(mini,2), round(maxi,2),round(ran,2)),\n",
        "    round(mean,2),\n",
        "    round(median,2)))                                                                                                                                                                         \n",
        "                                                                                                   "
      ],
      "metadata": {
        "id": "zZiiX_BvMW24"
      },
      "execution_count": 30,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "UVA_numeric (df,employee)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 1000
        },
        "id": "sgzAGYEhNZa3",
        "outputId": "c664b1fb-cbd6-4b01-8a82-eff8ce89b340"
      },
      "execution_count": 39,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stderr",
          "text": [
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n"
          ]
        },
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 4200x300 with 6 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "UVA_numeric(df,customer_details)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 959
        },
        "id": "xiwuiomoSJqf",
        "outputId": "81422cda-9da8-4cd2-df54-0907d15f3218"
      },
      "execution_count": 41,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stderr",
          "text": [
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n"
          ]
        },
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 2800x300 with 4 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "# custom function for easy outlier analysis\n",
        "\n",
        "def UVA_outlier(df, var_group, include_outlier = True):\n",
        "  '''\n",
        "  Univariate_Analysis_outlier:\n",
        "  takes a group of variables (INTEGER and FLOAT) and plot/print boplot and descriptives\\n\n",
        "  Runs a loop: calculate all the descriptives of i(th) variable and plot/print it \\n\\n\n",
        "\n",
        "  data : dataframe from which to plot from\\n\n",
        "  var_group : {list} type Group of Continuous variables\\n\n",
        "  include_outlier : {bool} whether to include outliers or not, default = True\\n\n",
        "  '''\n",
        "  size = len(var_group)\n",
        "  plt.figure(figsize = (7*size,4), dpi = 100)\n",
        "  \n",
        "  #looping for each variable\n",
        "  for j,i in enumerate(var_group):\n",
        "    \n",
        "    # calculating descriptives of variable\n",
        "    quant25 = df[i].quantile(0.25)\n",
        "    quant75 = df[i].quantile(0.75)\n",
        "    IQR = quant75 - quant25\n",
        "    med = df[i].median()\n",
        "    whis_low = quant25-(1.5*IQR)\n",
        "    whis_high = quant75+(1.5*IQR)\n",
        "     # Calculating Number of Outliers\n",
        "    outlier_high = len(df[i][df[i]>whis_high])\n",
        "    outlier_low = len(df[i][df[i]<whis_low])\n",
        "\n",
        "    if include_outlier == True:\n",
        "      #Plotting the variable with every information\n",
        "      plt.subplot(1,size,j+1)\n",
        "      sns.boxplot(df[i], orient=\"v\")\n",
        "      plt.ylabel('{}'.format(i))\n",
        "      plt.title('With Outliers\\nIQR = {}; Median = {} \\n 2nd,3rd  quartile = {};\\n Outlier (low/high) = {} \\n'.format(\n",
        "          \n",
        "round(IQR,2),\n",
        "round(med,2),\n",
        "(round(quant25,2),round(quant75,2)),\n",
        "(outlier_low,outlier_high)\n",
        "))\n",
        "    else:\n",
        "      # replacing outliers with max/min whisker\n",
        "      df2 = df[var_group][:]\n",
        "      df2[i][df2[i]>whis_high] = whis_high+1\n",
        "      df2[i][df2[i]<whis_low] = whis_low-1\n",
        "      \n",
        "      # plotting without outliers\n",
        "      plt.subplot(1,size,j+1)\n",
        "      sns.boxplot(df2[i], orient=\"v\")\n",
        "      plt.ylabel('{}'.format(i))\n",
        "      plt.title('Without Outliers\\nIQR = {}; Median = {} \\n 2nd,3rd  quartile = {};\\n Outlier (low/high) = {} \\n'.format(\n",
        "      round(IQR,2), \n",
        "      round(med,2),\n",
        "      (round(quant25,2),round(quant75,2)) \n",
        "      (outlier_low,outlier_high)\n",
        "      )) \n",
        "                                                                                                   "
      ],
      "metadata": {
        "id": "PteH2skSTMwg"
      },
      "execution_count": 44,
      "outputs": []
    },
    {
      "cell_type": "code",
      "source": [
        "UVA_outlier(df, customer_details)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 785
        },
        "id": "yH_7HUd6VUtI",
        "outputId": "d92d9eba-45d2-4764-ce12-ad5066f7f7e2"
      },
      "execution_count": 46,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stderr",
          "text": [
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n",
            "  warnings.warn(single_var_warning.format(\"Vertical\", \"x\"))\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n",
            "  warnings.warn(single_var_warning.format(\"Vertical\", \"x\"))\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n",
            "  warnings.warn(single_var_warning.format(\"Vertical\", \"x\"))\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n",
            "  warnings.warn(single_var_warning.format(\"Vertical\", \"x\"))\n"
          ]
        },
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 2800x400 with 4 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    },
    {
      "cell_type": "code",
      "source": [
        "UVA_outlier(df, customer_details, include_outlier= False)"
      ],
      "metadata": {
        "colab": {
          "base_uri": "https://localhost:8080/",
          "height": 785
        },
        "id": "CB2ADxUXZUub",
        "outputId": "43cf853c-c701-41a5-b8e8-218e09198af0"
      },
      "execution_count": 62,
      "outputs": [
        {
          "output_type": "stream",
          "name": "stderr",
          "text": [
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n",
            "  warnings.warn(single_var_warning.format(\"Vertical\", \"x\"))\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n",
            "  warnings.warn(single_var_warning.format(\"Vertical\", \"x\"))\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n",
            "  warnings.warn(single_var_warning.format(\"Vertical\", \"x\"))\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
            "  FutureWarning\n",
            "/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n",
            "  warnings.warn(single_var_warning.format(\"Vertical\", \"x\"))\n"
          ]
        },
        {
          "output_type": "display_data",
          "data": {
            "text/plain": [
              "<Figure size 2800x400 with 4 Axes>"
            ],
            "image/png": "...\n"
          },
          "metadata": {
            "needs_background": "light"
          }
        }
      ]
    }
  ]
}
# Out:
# {'nbformat': 4,
#  'nbformat_minor': 0,
#  'metadata': {'colab': {'provenance': [], 'collapsed_sections': []},
#   'kernelspec': {'name': 'python3', 'display_name': 'Python 3'},
#   'language_info': {'name': 'python'}},
#  'cells': [{'cell_type': 'code',
#    'execution_count': 1,
#    'metadata': {'id': 'z1hGeSTG8hsr'},
#    'outputs': [],
#    'source': ['import numpy as np\n', 'import pandas as pd']},
#   {'cell_type': 'code',
#    'source': ['df = pd.read_csv("/content/Churn_Modelling.csv")'],
#    'metadata': {'id': 'k8PIAfPN88Ql'},
#    'execution_count': 2,
#    'outputs': []},
#   {'cell_type': 'code',
#    'source': ['df.shape'],
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'F-lmqBV59BFO',
#     'outputId': '4adc7411-dfa9-4640-dd47-5c228670f12a'},
#    'execution_count': 3,
#    'outputs': [{'output_type': 'execute_result',
#      'data': {'text/plain': ['(10000, 14)']},
#      'metadata': {},
#      'execution_count': 3}]},
#   {'cell_type': 'code',
#    'source': ['df.head()'],
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/',
#      'height': 270},
#     'id': 'p3CnQqUy9FB5',
#     'outputId': 'b16ac48b-eaa1-4c34-e549-68a46cb4804a'},
#    'execution_count': 4,
#    'outputs': [{'output_type': 'execute_result',
#      'data': {'text/plain': ['   RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \\\n',
#        '0          1    15634602  Hargrave          619    France  Female   42   \n',
#        '1          2    15647311      Hill          608     Spain  Female   41   \n',
#        '2          3    15619304      Onio          502    France  Female   42   \n',
#        '3          4    15701354      Boni          699    France  Female   39   \n',
#        '4          5    15737888  Mitchell          850     Spain  Female   43   \n',
#        '\n',
#        '   Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \\\n',
#        '0       2       0.00              1          1               1   \n',
#        '1       1   83807.86              1          0               1   \n',
#        '2       8  159660.80              3          1               0   \n',
#        '3       1       0.00              2          0               0   \n',
#        '4       2  125510.82              1          1               1   \n',
#        '\n',
#        '   EstimatedSalary  Exited  \n',
#        '0        101348.88       1  \n',
#        '1        112542.58       0  \n',
#        '2        113931.57       1  \n',
#        '3         93826.63       0  \n',
#        '4         79084.10       0  '],
#       'text/html': ['\n',
#        '  <div id="df-ed8c1e58-c02a-4a9d-bdc9-7b0392bd6daa">\n',
#        '    <div class="colab-df-container">\n',
#        '      <div>\n',
#        '<style scoped>\n',
#        '    .dataframe tbody tr th:only-of-type {\n',
#        '        vertical-align: middle;\n',
#        '    }\n',
#        '\n',
#        '    .dataframe tbody tr th {\n',
#        '        vertical-align: top;\n',
#        '    }\n',
#        '\n',
#        '    .dataframe thead th {\n',
#        '        text-align: right;\n',
#        '    }\n',
#        '</style>\n',
#        '<table border="1" class="dataframe">\n',
#        '  <thead>\n',
#        '    <tr style="text-align: right;">\n',
#        '      <th></th>\n',
#        '      <th>RowNumber</th>\n',
#        '      <th>CustomerId</th>\n',
#        '      <th>Surname</th>\n',
#        '      <th>CreditScore</th>\n',
#        '      <th>Geography</th>\n',
#        '      <th>Gender</th>\n',
#        '      <th>Age</th>\n',
#        '      <th>Tenure</th>\n',
#        '      <th>Balance</th>\n',
#        '      <th>NumOfProducts</th>\n',
#        '      <th>HasCrCard</th>\n',
#        '      <th>IsActiveMember</th>\n',
#        '      <th>EstimatedSalary</th>\n',
#        '      <th>Exited</th>\n',
#        '    </tr>\n',
#        '  </thead>\n',
#        '  <tbody>\n',
#        '    <tr>\n',
#        '      <th>0</th>\n',
#        '      <td>1</td>\n',
#        '      <td>15634602</td>\n',
#        '      <td>Hargrave</td>\n',
#        '      <td>619</td>\n',
#        '      <td>France</td>\n',
#        '      <td>Female</td>\n',
#        '      <td>42</td>\n',
#        '      <td>2</td>\n',
#        '      <td>0.00</td>\n',
#        '      <td>1</td>\n',
#        '      <td>1</td>\n',
#        '      <td>1</td>\n',
#        '      <td>101348.88</td>\n',
#        '      <td>1</td>\n',
#        '    </tr>\n',
#        '    <tr>\n',
#        '      <th>1</th>\n',
#        '      <td>2</td>\n',
#        '      <td>15647311</td>\n',
#        '      <td>Hill</td>\n',
#        '      <td>608</td>\n',
#        '      <td>Spain</td>\n',
#        '      <td>Female</td>\n',
#        '      <td>41</td>\n',
#        '      <td>1</td>\n',
#        '      <td>83807.86</td>\n',
#        '      <td>1</td>\n',
#        '      <td>0</td>\n',
#        '      <td>1</td>\n',
#        '      <td>112542.58</td>\n',
#        '      <td>0</td>\n',
#        '    </tr>\n',
#        '    <tr>\n',
#        '      <th>2</th>\n',
#        '      <td>3</td>\n',
#        '      <td>15619304</td>\n',
#        '      <td>Onio</td>\n',
#        '      <td>502</td>\n',
#        '      <td>France</td>\n',
#        '      <td>Female</td>\n',
#        '      <td>42</td>\n',
#        '      <td>8</td>\n',
#        '      <td>159660.80</td>\n',
#        '      <td>3</td>\n',
#        '      <td>1</td>\n',
#        '      <td>0</td>\n',
#        '      <td>113931.57</td>\n',
#        '      <td>1</td>\n',
#        '    </tr>\n',
#        '    <tr>\n',
#        '      <th>3</th>\n',
#        '      <td>4</td>\n',
#        '      <td>15701354</td>\n',
#        '      <td>Boni</td>\n',
#        '      <td>699</td>\n',
#        '      <td>France</td>\n',
#        '      <td>Female</td>\n',
#        '      <td>39</td>\n',
#        '      <td>1</td>\n',
#        '      <td>0.00</td>\n',
#        '      <td>2</td>\n',
#        '      <td>0</td>\n',
#        '      <td>0</td>\n',
#        '      <td>93826.63</td>\n',
#        '      <td>0</td>\n',
#        '    </tr>\n',
#        '    <tr>\n',
#        '      <th>4</th>\n',
#        '      <td>5</td>\n',
#        '      <td>15737888</td>\n',
#        '      <td>Mitchell</td>\n',
#        '      <td>850</td>\n',
#        '      <td>Spain</td>\n',
#        '      <td>Female</td>\n',
#        '      <td>43</td>\n',
#        '      <td>2</td>\n',
#        '      <td>125510.82</td>\n',
#        '      <td>1</td>\n',
#        '      <td>1</td>\n',
#        '      <td>1</td>\n',
#        '      <td>79084.10</td>\n',
#        '      <td>0</td>\n',
#        '    </tr>\n',
#        '  </tbody>\n',
#        '</table>\n',
#        '</div>\n',
#        '      <button class="colab-df-convert" onclick="convertToInteractive(\'df-ed8c1e58-c02a-4a9d-bdc9-7b0392bd6daa\')"\n',
#        '              title="Convert this dataframe to an interactive table."\n',
#        '              style="display:none;">\n',
#        '        \n',
#        '  <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"\n',
#        '       width="24px">\n',
#        '    <path d="M0 0h24v24H0V0z" fill="none"/>\n',
#        '    <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>\n',
#        '  </svg>\n',
#        '      </button>\n',
#        '      \n',
#        '  <style>\n',
#        '    .colab-df-container {\n',
#        '      display:flex;\n',
#        '      flex-wrap:wrap;\n',
#        '      gap: 12px;\n',
#        '    }\n',
#        '\n',
#        '    .colab-df-convert {\n',
#        '      background-color: #E8F0FE;\n',
#        '      border: none;\n',
#        '      border-radius: 50%;\n',
#        '      cursor: pointer;\n',
#        '      display: none;\n',
#        '      fill: #1967D2;\n',
#        '      height: 32px;\n',
#        '      padding: 0 0 0 0;\n',
#        '      width: 32px;\n',
#        '    }\n',
#        '\n',
#        '    .colab-df-convert:hover {\n',
#        '      background-color: #E2EBFA;\n',
#        '      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n',
#        '      fill: #174EA6;\n',
#        '    }\n',
#        '\n',
#        '    [theme=dark] .colab-df-convert {\n',
#        '      background-color: #3B4455;\n',
#        '      fill: #D2E3FC;\n',
#        '    }\n',
#        '\n',
#        '    [theme=dark] .colab-df-convert:hover {\n',
#        '      background-color: #434B5C;\n',
#        '      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n',
#        '      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n',
#        '      fill: #FFFFFF;\n',
#        '    }\n',
#        '  </style>\n',
#        '\n',
#        '      <script>\n',
#        '        const buttonEl =\n',
#        "          document.querySelector('#df-ed8c1e58-c02a-4a9d-bdc9-7b0392bd6daa button.colab-df-convert');\n",
#        '        buttonEl.style.display =\n',
#        "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
#        '\n',
#        '        async function convertToInteractive(key) {\n',
#        "          const element = document.querySelector('#df-ed8c1e58-c02a-4a9d-bdc9-7b0392bd6daa');\n",
#        '          const dataTable =\n',
#        "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
#        '                                                     [key], {});\n',
#        '          if (!dataTable) return;\n',
#        '\n',
#        "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
#        '            \'<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>\'\n',
#        "            + ' to learn more about interactive tables.';\n",
#        "          element.innerHTML = '';\n",
#        "          dataTable['output_type'] = 'display_data';\n",
#        '          await google.colab.output.renderOutput(dataTable, element);\n',
#        "          const docLink = document.createElement('div');\n",
#        '          docLink.innerHTML = docLinkHtml;\n',
#        '          element.appendChild(docLink);\n',
#        '        }\n',
#        '      </script>\n',
#        '    </div>\n',
#        '  </div>\n',
#        '  ']},
#      'metadata': {},
#      'execution_count': 4}]},
#   {'cell_type': 'code',
#    'source': ["df.groupby(['Geography']).count()"],
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/',
#      'height': 239},
#     'id': 'zSPPGqAn9Z-z',
#     'outputId': '794dfc41-bbfd-41b6-f350-1155fdc3fc82'},
#    'execution_count': 5,
#    'outputs': [{'output_type': 'execute_result',
#      'data': {'text/plain': ['           RowNumber  CustomerId  Surname  CreditScore  Gender   Age  Tenure  \\\n',
#        'Geography                                                                      \n',
#        'France          5014        5014     5014         5014    5014  5014    5014   \n',
#        'Germany         2509        2509     2509         2509    2509  2509    2509   \n',
#        'Spain           2477        2477     2477         2477    2477  2477    2477   \n',
#        '\n',
#        '           Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \\\n',
#        'Geography                                                                       \n',
#        'France        5014           5014       5014            5014             5014   \n',
#        'Germany       2509           2509       2509            2509             2509   \n',
#        'Spain         2477           2477       2477            2477             2477   \n',
#        '\n',
#        '           Exited  \n',
#        'Geography          \n',
#        'France       5014  \n',
#        'Germany      2509  \n',
#        'Spain        2477  '],
#       'text/html': ['\n',
#        '  <div id="df-a16eea86-dd25-4d83-9774-8d9243de3932">\n',
#        '    <div class="colab-df-container">\n',
#        '      <div>\n',
#        '<style scoped>\n',
#        '    .dataframe tbody tr th:only-of-type {\n',
#        '        vertical-align: middle;\n',
#        '    }\n',
#        '\n',
#        '    .dataframe tbody tr th {\n',
#        '        vertical-align: top;\n',
#        '    }\n',
#        '\n',
#        '    .dataframe thead th {\n',
#        '        text-align: right;\n',
#        '    }\n',
#        '</style>\n',
#        '<table border="1" class="dataframe">\n',
#        '  <thead>\n',
#        '    <tr style="text-align: right;">\n',
#        '      <th></th>\n',
#        '      <th>RowNumber</th>\n',
#        '      <th>CustomerId</th>\n',
#        '      <th>Surname</th>\n',
#        '      <th>CreditScore</th>\n',
#        '      <th>Gender</th>\n',
#        '      <th>Age</th>\n',
#        '      <th>Tenure</th>\n',
#        '      <th>Balance</th>\n',
#        '      <th>NumOfProducts</th>\n',
#        '      <th>HasCrCard</th>\n',
#        '      <th>IsActiveMember</th>\n',
#        '      <th>EstimatedSalary</th>\n',
#        '      <th>Exited</th>\n',
#        '    </tr>\n',
#        '    <tr>\n',
#        '      <th>Geography</th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '    </tr>\n',
#        '  </thead>\n',
#        '  <tbody>\n',
#        '    <tr>\n',
#        '      <th>France</th>\n',
#        '      <td>5014</td>\n',
#        '      <td>5014</td>\n',
#        '      <td>5014</td>\n',
#        '      <td>5014</td>\n',
#        '      <td>5014</td>\n',
#        '      <td>5014</td>\n',
#        '      <td>5014</td>\n',
#        '      <td>5014</td>\n',
#        '      <td>5014</td>\n',
#        '      <td>5014</td>\n',
#        '      <td>5014</td>\n',
#        '      <td>5014</td>\n',
#        '      <td>5014</td>\n',
#        '    </tr>\n',
#        '    <tr>\n',
#        '      <th>Germany</th>\n',
#        '      <td>2509</td>\n',
#        '      <td>2509</td>\n',
#        '      <td>2509</td>\n',
#        '      <td>2509</td>\n',
#        '      <td>2509</td>\n',
#        '      <td>2509</td>\n',
#        '      <td>2509</td>\n',
#        '      <td>2509</td>\n',
#        '      <td>2509</td>\n',
#        '      <td>2509</td>\n',
#        '      <td>2509</td>\n',
#        '      <td>2509</td>\n',
#        '      <td>2509</td>\n',
#        '    </tr>\n',
#        '    <tr>\n',
#        '      <th>Spain</th>\n',
#        '      <td>2477</td>\n',
#        '      <td>2477</td>\n',
#        '      <td>2477</td>\n',
#        '      <td>2477</td>\n',
#        '      <td>2477</td>\n',
#        '      <td>2477</td>\n',
#        '      <td>2477</td>\n',
#        '      <td>2477</td>\n',
#        '      <td>2477</td>\n',
#        '      <td>2477</td>\n',
#        '      <td>2477</td>\n',
#        '      <td>2477</td>\n',
#        '      <td>2477</td>\n',
#        '    </tr>\n',
#        '  </tbody>\n',
#        '</table>\n',
#        '</div>\n',
#        '      <button class="colab-df-convert" onclick="convertToInteractive(\'df-a16eea86-dd25-4d83-9774-8d9243de3932\')"\n',
#        '              title="Convert this dataframe to an interactive table."\n',
#        '              style="display:none;">\n',
#        '        \n',
#        '  <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"\n',
#        '       width="24px">\n',
#        '    <path d="M0 0h24v24H0V0z" fill="none"/>\n',
#        '    <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>\n',
#        '  </svg>\n',
#        '      </button>\n',
#        '      \n',
#        '  <style>\n',
#        '    .colab-df-container {\n',
#        '      display:flex;\n',
#        '      flex-wrap:wrap;\n',
#        '      gap: 12px;\n',
#        '    }\n',
#        '\n',
#        '    .colab-df-convert {\n',
#        '      background-color: #E8F0FE;\n',
#        '      border: none;\n',
#        '      border-radius: 50%;\n',
#        '      cursor: pointer;\n',
#        '      display: none;\n',
#        '      fill: #1967D2;\n',
#        '      height: 32px;\n',
#        '      padding: 0 0 0 0;\n',
#        '      width: 32px;\n',
#        '    }\n',
#        '\n',
#        '    .colab-df-convert:hover {\n',
#        '      background-color: #E2EBFA;\n',
#        '      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n',
#        '      fill: #174EA6;\n',
#        '    }\n',
#        '\n',
#        '    [theme=dark] .colab-df-convert {\n',
#        '      background-color: #3B4455;\n',
#        '      fill: #D2E3FC;\n',
#        '    }\n',
#        '\n',
#        '    [theme=dark] .colab-df-convert:hover {\n',
#        '      background-color: #434B5C;\n',
#        '      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n',
#        '      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n',
#        '      fill: #FFFFFF;\n',
#        '    }\n',
#        '  </style>\n',
#        '\n',
#        '      <script>\n',
#        '        const buttonEl =\n',
#        "          document.querySelector('#df-a16eea86-dd25-4d83-9774-8d9243de3932 button.colab-df-convert');\n",
#        '        buttonEl.style.display =\n',
#        "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
#        '\n',
#        '        async function convertToInteractive(key) {\n',
#        "          const element = document.querySelector('#df-a16eea86-dd25-4d83-9774-8d9243de3932');\n",
#        '          const dataTable =\n',
#        "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
#        '                                                     [key], {});\n',
#        '          if (!dataTable) return;\n',
#        '\n',
#        "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
#        '            \'<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>\'\n',
#        "            + ' to learn more about interactive tables.';\n",
#        "          element.innerHTML = '';\n",
#        "          dataTable['output_type'] = 'display_data';\n",
#        '          await google.colab.output.renderOutput(dataTable, element);\n',
#        "          const docLink = document.createElement('div');\n",
#        '          docLink.innerHTML = docLinkHtml;\n',
#        '          element.appendChild(docLink);\n',
#        '        }\n',
#        '      </script>\n',
#        '    </div>\n',
#        '  </div>\n',
#        '  ']},
#      'metadata': {},
#      'execution_count': 5}]},
#   {'cell_type': 'code',
#    'source': ["df.groupby(['Gender']).count()\n"],
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/',
#      'height': 207},
#     'id': 'dC3rEENL-7EJ',
#     'outputId': '55683982-8beb-404c-e897-ce3f2249c806'},
#    'execution_count': 6,
#    'outputs': [{'output_type': 'execute_result',
#      'data': {'text/plain': ['        RowNumber  CustomerId  Surname  CreditScore  Geography   Age  Tenure  \\\n',
#        'Gender                                                                         \n',
#        'Female       4543        4543     4543         4543       4543  4543    4543   \n',
#        'Male         5457        5457     5457         5457       5457  5457    5457   \n',
#        '\n',
#        '        Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \\\n',
#        'Gender                                                                       \n',
#        'Female     4543           4543       4543            4543             4543   \n',
#        'Male       5457           5457       5457            5457             5457   \n',
#        '\n',
#        '        Exited  \n',
#        'Gender          \n',
#        'Female    4543  \n',
#        'Male      5457  '],
#       'text/html': ['\n',
#        '  <div id="df-adb81ed6-b9c9-4de1-a480-a997d97cb36e">\n',
#        '    <div class="colab-df-container">\n',
#        '      <div>\n',
#        '<style scoped>\n',
#        '    .dataframe tbody tr th:only-of-type {\n',
#        '        vertical-align: middle;\n',
#        '    }\n',
#        '\n',
#        '    .dataframe tbody tr th {\n',
#        '        vertical-align: top;\n',
#        '    }\n',
#        '\n',
#        '    .dataframe thead th {\n',
#        '        text-align: right;\n',
#        '    }\n',
#        '</style>\n',
#        '<table border="1" class="dataframe">\n',
#        '  <thead>\n',
#        '    <tr style="text-align: right;">\n',
#        '      <th></th>\n',
#        '      <th>RowNumber</th>\n',
#        '      <th>CustomerId</th>\n',
#        '      <th>Surname</th>\n',
#        '      <th>CreditScore</th>\n',
#        '      <th>Geography</th>\n',
#        '      <th>Age</th>\n',
#        '      <th>Tenure</th>\n',
#        '      <th>Balance</th>\n',
#        '      <th>NumOfProducts</th>\n',
#        '      <th>HasCrCard</th>\n',
#        '      <th>IsActiveMember</th>\n',
#        '      <th>EstimatedSalary</th>\n',
#        '      <th>Exited</th>\n',
#        '    </tr>\n',
#        '    <tr>\n',
#        '      <th>Gender</th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '      <th></th>\n',
#        '    </tr>\n',
#        '  </thead>\n',
#        '  <tbody>\n',
#        '    <tr>\n',
#        '      <th>Female</th>\n',
#        '      <td>4543</td>\n',
#        '      <td>4543</td>\n',
#        '      <td>4543</td>\n',
#        '      <td>4543</td>\n',
#        '      <td>4543</td>\n',
#        '      <td>4543</td>\n',
#        '      <td>4543</td>\n',
#        '      <td>4543</td>\n',
#        '      <td>4543</td>\n',
#        '      <td>4543</td>\n',
#        '      <td>4543</td>\n',
#        '      <td>4543</td>\n',
#        '      <td>4543</td>\n',
#        '    </tr>\n',
#        '    <tr>\n',
#        '      <th>Male</th>\n',
#        '      <td>5457</td>\n',
#        '      <td>5457</td>\n',
#        '      <td>5457</td>\n',
#        '      <td>5457</td>\n',
#        '      <td>5457</td>\n',
#        '      <td>5457</td>\n',
#        '      <td>5457</td>\n',
#        '      <td>5457</td>\n',
#        '      <td>5457</td>\n',
#        '      <td>5457</td>\n',
#        '      <td>5457</td>\n',
#        '      <td>5457</td>\n',
#        '      <td>5457</td>\n',
#        '    </tr>\n',
#        '  </tbody>\n',
#        '</table>\n',
#        '</div>\n',
#        '      <button class="colab-df-convert" onclick="convertToInteractive(\'df-adb81ed6-b9c9-4de1-a480-a997d97cb36e\')"\n',
#        '              title="Convert this dataframe to an interactive table."\n',
#        '              style="display:none;">\n',
#        '        \n',
#        '  <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"\n',
#        '       width="24px">\n',
#        '    <path d="M0 0h24v24H0V0z" fill="none"/>\n',
#        '    <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>\n',
#        '  </svg>\n',
#        '      </button>\n',
#        '      \n',
#        '  <style>\n',
#        '    .colab-df-container {\n',
#        '      display:flex;\n',
#        '      flex-wrap:wrap;\n',
#        '      gap: 12px;\n',
#        '    }\n',
#        '\n',
#        '    .colab-df-convert {\n',
#        '      background-color: #E8F0FE;\n',
#        '      border: none;\n',
#        '      border-radius: 50%;\n',
#        '      cursor: pointer;\n',
#        '      display: none;\n',
#        '      fill: #1967D2;\n',
#        '      height: 32px;\n',
#        '      padding: 0 0 0 0;\n',
#        '      width: 32px;\n',
#        '    }\n',
#        '\n',
#        '    .colab-df-convert:hover {\n',
#        '      background-color: #E2EBFA;\n',
#        '      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n',
#        '      fill: #174EA6;\n',
#        '    }\n',
#        '\n',
#        '    [theme=dark] .colab-df-convert {\n',
#        '      background-color: #3B4455;\n',
#        '      fill: #D2E3FC;\n',
#        '    }\n',
#        '\n',
#        '    [theme=dark] .colab-df-convert:hover {\n',
#        '      background-color: #434B5C;\n',
#        '      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n',
#        '      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n',
#        '      fill: #FFFFFF;\n',
#        '    }\n',
#        '  </style>\n',
#        '\n',
#        '      <script>\n',
#        '        const buttonEl =\n',
#        "          document.querySelector('#df-adb81ed6-b9c9-4de1-a480-a997d97cb36e button.colab-df-convert');\n",
#        '        buttonEl.style.display =\n',
#        "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
#        '\n',
#        '        async function convertToInteractive(key) {\n',
#        "          const element = document.querySelector('#df-adb81ed6-b9c9-4de1-a480-a997d97cb36e');\n",
#        '          const dataTable =\n',
#        "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
#        '                                                     [key], {});\n',
#        '          if (!dataTable) return;\n',
#        '\n',
#        "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
#        '            \'<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>\'\n',
#        "            + ' to learn more about interactive tables.';\n",
#        "          element.innerHTML = '';\n",
#        "          dataTable['output_type'] = 'display_data';\n",
#        '          await google.colab.output.renderOutput(dataTable, element);\n',
#        "          const docLink = document.createElement('div');\n",
#        '          docLink.innerHTML = docLinkHtml;\n',
#        '          element.appendChild(docLink);\n',
#        '        }\n',
#        '      </script>\n',
#        '    </div>\n',
#        '  </div>\n',
#        '  ']},
#      'metadata': {},
#      'execution_count': 6}]},
#   {'cell_type': 'code',
#    'source': ["freq_table = df.groupby(['Geography']).size().reset_index(name='Count').rename(columns={'Geography':'Geography'})\n",
#     'freq_table'],
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/',
#      'height': 143},
#     'id': '5pxroRhR_PEc',
#     'outputId': '59778021-b256-42f8-9d66-86e20d78d557'},
#    'execution_count': 8,
#    'outputs': [{'output_type': 'execute_result',
#      'data': {'text/plain': ['  Geography  Count\n',
#        '0    France   5014\n',
#        '1   Germany   2509\n',
#        '2     Spain   2477'],
#       'text/html': ['\n',
#        '  <div id="df-cefd63f6-d890-4404-932b-412777a9992d">\n',
#        '    <div class="colab-df-container">\n',
#        '      <div>\n',
#        '<style scoped>\n',
#        '    .dataframe tbody tr th:only-of-type {\n',
#        '        vertical-align: middle;\n',
#        '    }\n',
#        '\n',
#        '    .dataframe tbody tr th {\n',
#        '        vertical-align: top;\n',
#        '    }\n',
#        '\n',
#        '    .dataframe thead th {\n',
#        '        text-align: right;\n',
#        '    }\n',
#        '</style>\n',
#        '<table border="1" class="dataframe">\n',
#        '  <thead>\n',
#        '    <tr style="text-align: right;">\n',
#        '      <th></th>\n',
#        '      <th>Geography</th>\n',
#        '      <th>Count</th>\n',
#        '    </tr>\n',
#        '  </thead>\n',
#        '  <tbody>\n',
#        '    <tr>\n',
#        '      <th>0</th>\n',
#        '      <td>France</td>\n',
#        '      <td>5014</td>\n',
#        '    </tr>\n',
#        '    <tr>\n',
#        '      <th>1</th>\n',
#        '      <td>Germany</td>\n',
#        '      <td>2509</td>\n',
#        '    </tr>\n',
#        '    <tr>\n',
#        '      <th>2</th>\n',
#        '      <td>Spain</td>\n',
#        '      <td>2477</td>\n',
#        '    </tr>\n',
#        '  </tbody>\n',
#        '</table>\n',
#        '</div>\n',
#        '      <button class="colab-df-convert" onclick="convertToInteractive(\'df-cefd63f6-d890-4404-932b-412777a9992d\')"\n',
#        '              title="Convert this dataframe to an interactive table."\n',
#        '              style="display:none;">\n',
#        '        \n',
#        '  <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"\n',
#        '       width="24px">\n',
#        '    <path d="M0 0h24v24H0V0z" fill="none"/>\n',
#        '    <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>\n',
#        '  </svg>\n',
#        '      </button>\n',
#        '      \n',
#        '  <style>\n',
#        '    .colab-df-container {\n',
#        '      display:flex;\n',
#        '      flex-wrap:wrap;\n',
#        '      gap: 12px;\n',
#        '    }\n',
#        '\n',
#        '    .colab-df-convert {\n',
#        '      background-color: #E8F0FE;\n',
#        '      border: none;\n',
#        '      border-radius: 50%;\n',
#        '      cursor: pointer;\n',
#        '      display: none;\n',
#        '      fill: #1967D2;\n',
#        '      height: 32px;\n',
#        '      padding: 0 0 0 0;\n',
#        '      width: 32px;\n',
#        '    }\n',
#        '\n',
#        '    .colab-df-convert:hover {\n',
#        '      background-color: #E2EBFA;\n',
#        '      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n',
#        '      fill: #174EA6;\n',
#        '    }\n',
#        '\n',
#        '    [theme=dark] .colab-df-convert {\n',
#        '      background-color: #3B4455;\n',
#        '      fill: #D2E3FC;\n',
#        '    }\n',
#        '\n',
#        '    [theme=dark] .colab-df-convert:hover {\n',
#        '      background-color: #434B5C;\n',
#        '      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n',
#        '      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n',
#        '      fill: #FFFFFF;\n',
#        '    }\n',
#        '  </style>\n',
#        '\n',
#        '      <script>\n',
#        '        const buttonEl =\n',
#        "          document.querySelector('#df-cefd63f6-d890-4404-932b-412777a9992d button.colab-df-convert');\n",
#        '        buttonEl.style.display =\n',
#        "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
#        '\n',
#        '        async function convertToInteractive(key) {\n',
#        "          const element = document.querySelector('#df-cefd63f6-d890-4404-932b-412777a9992d');\n",
#        '          const dataTable =\n',
#        "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
#        '                                                     [key], {});\n',
#        '          if (!dataTable) return;\n',
#        '\n',
#        "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
#        '            \'<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>\'\n',
#        "            + ' to learn more about interactive tables.';\n",
#        "          element.innerHTML = '';\n",
#        "          dataTable['output_type'] = 'display_data';\n",
#        '          await google.colab.output.renderOutput(dataTable, element);\n',
#        "          const docLink = document.createElement('div');\n",
#        '          docLink.innerHTML = docLinkHtml;\n',
#        '          element.appendChild(docLink);\n',
#        '        }\n',
#        '      </script>\n',
#        '    </div>\n',
#        '  </div>\n',
#        '  ']},
#      'metadata': {},
#      'execution_count': 8}]},
#   {'cell_type': 'code',
#    'source': ["freq_table = df.groupby(['Gender']).size().reset_index(name='Count').rename(columns={'Gender':'Gender'})\n",
#     'freq_table'],
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/',
#      'height': 112},
#     'id': 'm5wyAhMgAuwo',
#     'outputId': '36c5cc5e-d5c3-42ee-9254-2927724c47e7'},
#    'execution_count': 9,
#    'outputs': [{'output_type': 'execute_result',
#      'data': {'text/plain': ['   Gender  Count\n',
#        '0  Female   4543\n',
#        '1    Male   5457'],
#       'text/html': ['\n',
#        '  <div id="df-39ff7570-ab2b-4f33-b08e-db8f43ea3e99">\n',
#        '    <div class="colab-df-container">\n',
#        '      <div>\n',
#        '<style scoped>\n',
#        '    .dataframe tbody tr th:only-of-type {\n',
#        '        vertical-align: middle;\n',
#        '    }\n',
#        '\n',
#        '    .dataframe tbody tr th {\n',
#        '        vertical-align: top;\n',
#        '    }\n',
#        '\n',
#        '    .dataframe thead th {\n',
#        '        text-align: right;\n',
#        '    }\n',
#        '</style>\n',
#        '<table border="1" class="dataframe">\n',
#        '  <thead>\n',
#        '    <tr style="text-align: right;">\n',
#        '      <th></th>\n',
#        '      <th>Gender</th>\n',
#        '      <th>Count</th>\n',
#        '    </tr>\n',
#        '  </thead>\n',
#        '  <tbody>\n',
#        '    <tr>\n',
#        '      <th>0</th>\n',
#        '      <td>Female</td>\n',
#        '      <td>4543</td>\n',
#        '    </tr>\n',
#        '    <tr>\n',
#        '      <th>1</th>\n',
#        '      <td>Male</td>\n',
#        '      <td>5457</td>\n',
#        '    </tr>\n',
#        '  </tbody>\n',
#        '</table>\n',
#        '</div>\n',
#        '      <button class="colab-df-convert" onclick="convertToInteractive(\'df-39ff7570-ab2b-4f33-b08e-db8f43ea3e99\')"\n',
#        '              title="Convert this dataframe to an interactive table."\n',
#        '              style="display:none;">\n',
#        '        \n',
#        '  <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"\n',
#        '       width="24px">\n',
#        '    <path d="M0 0h24v24H0V0z" fill="none"/>\n',
#        '    <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>\n',
#        '  </svg>\n',
#        '      </button>\n',
#        '      \n',
#        '  <style>\n',
#        '    .colab-df-container {\n',
#        '      display:flex;\n',
#        '      flex-wrap:wrap;\n',
#        '      gap: 12px;\n',
#        '    }\n',
#        '\n',
#        '    .colab-df-convert {\n',
#        '      background-color: #E8F0FE;\n',
#        '      border: none;\n',
#        '      border-radius: 50%;\n',
#        '      cursor: pointer;\n',
#        '      display: none;\n',
#        '      fill: #1967D2;\n',
#        '      height: 32px;\n',
#        '      padding: 0 0 0 0;\n',
#        '      width: 32px;\n',
#        '    }\n',
#        '\n',
#        '    .colab-df-convert:hover {\n',
#        '      background-color: #E2EBFA;\n',
#        '      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n',
#        '      fill: #174EA6;\n',
#        '    }\n',
#        '\n',
#        '    [theme=dark] .colab-df-convert {\n',
#        '      background-color: #3B4455;\n',
#        '      fill: #D2E3FC;\n',
#        '    }\n',
#        '\n',
#        '    [theme=dark] .colab-df-convert:hover {\n',
#        '      background-color: #434B5C;\n',
#        '      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n',
#        '      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n',
#        '      fill: #FFFFFF;\n',
#        '    }\n',
#        '  </style>\n',
#        '\n',
#        '      <script>\n',
#        '        const buttonEl =\n',
#        "          document.querySelector('#df-39ff7570-ab2b-4f33-b08e-db8f43ea3e99 button.colab-df-convert');\n",
#        '        buttonEl.style.display =\n',
#        "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
#        '\n',
#        '        async function convertToInteractive(key) {\n',
#        "          const element = document.querySelector('#df-39ff7570-ab2b-4f33-b08e-db8f43ea3e99');\n",
#        '          const dataTable =\n',
#        "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
#        '                                                     [key], {});\n',
#        '          if (!dataTable) return;\n',
#        '\n',
#        "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
#        '            \'<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>\'\n',
#        "            + ' to learn more about interactive tables.';\n",
#        "          element.innerHTML = '';\n",
#        "          dataTable['output_type'] = 'display_data';\n",
#        '          await google.colab.output.renderOutput(dataTable, element);\n',
#        "          const docLink = document.createElement('div');\n",
#        '          docLink.innerHTML = docLinkHtml;\n',
#        '          element.appendChild(docLink);\n',
#        '        }\n',
#        '      </script>\n',
#        '    </div>\n',
#        '  </div>\n',
#        '  ']},
#      'metadata': {},
#      'execution_count': 9}]},
#   {'cell_type': 'code',
#    'source': ['import matplotlib.pyplot as plt\n',
#     'import seaborn as sns\n',
#     '%matplotlib inline'],
#    'metadata': {'id': 'XSfx6PSlBF1T'},
#    'execution_count': 11,
#    'outputs': []},
#   {'cell_type': 'code',
#    'source': ["plt.bar(freq_table['Gender'], freq_table['Count'])\n",
#     'plt.show()'],
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/',
#      'height': 265},
#     'id': '5tT5acr8BTay',
#     'outputId': '58c25e3c-cc07-421a-fd5d-86fff27a2381'},
#    'execution_count': 14,
#    'outputs': [{'output_type': 'display_data',
#      'data': {'text/plain': ['<Figure size 432x288 with 1 Axes>'],
#       'image/png': '...\n'},
#      'metadata': {'needs_background': 'light'}}]},
#   {'cell_type': 'code',
#    'source': ["freq_table['Count%'] = freq_table['Count']/sum(freq_table['Count'])*100\n",
#     'freq_table'],
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/',
#      'height': 112},
#     'id': 'Vh37rJrIDlEW',
#     'outputId': 'f91f3e0b-8c4d-4ddb-8f55-c196ef6221ed'},
#    'execution_count': 16,
#    'outputs': [{'output_type': 'execute_result',
#      'data': {'text/plain': ['   Gender  Count  Count%\n',
#        '0  Female   4543   45.43\n',
#        '1    Male   5457   54.57'],
#       'text/html': ['\n',
#        '  <div id="df-6eb12a06-e931-43a7-bd6d-968ca7d06ed0">\n',
#        '    <div class="colab-df-container">\n',
#        '      <div>\n',
#        '<style scoped>\n',
#        '    .dataframe tbody tr th:only-of-type {\n',
#        '        vertical-align: middle;\n',
#        '    }\n',
#        '\n',
#        '    .dataframe tbody tr th {\n',
#        '        vertical-align: top;\n',
#        '    }\n',
#        '\n',
#        '    .dataframe thead th {\n',
#        '        text-align: right;\n',
#        '    }\n',
#        '</style>\n',
#        '<table border="1" class="dataframe">\n',
#        '  <thead>\n',
#        '    <tr style="text-align: right;">\n',
#        '      <th></th>\n',
#        '      <th>Gender</th>\n',
#        '      <th>Count</th>\n',
#        '      <th>Count%</th>\n',
#        '    </tr>\n',
#        '  </thead>\n',
#        '  <tbody>\n',
#        '    <tr>\n',
#        '      <th>0</th>\n',
#        '      <td>Female</td>\n',
#        '      <td>4543</td>\n',
#        '      <td>45.43</td>\n',
#        '    </tr>\n',
#        '    <tr>\n',
#        '      <th>1</th>\n',
#        '      <td>Male</td>\n',
#        '      <td>5457</td>\n',
#        '      <td>54.57</td>\n',
#        '    </tr>\n',
#        '  </tbody>\n',
#        '</table>\n',
#        '</div>\n',
#        '      <button class="colab-df-convert" onclick="convertToInteractive(\'df-6eb12a06-e931-43a7-bd6d-968ca7d06ed0\')"\n',
#        '              title="Convert this dataframe to an interactive table."\n',
#        '              style="display:none;">\n',
#        '        \n',
#        '  <svg xmlns="http://www.w3.org/2000/svg" height="24px"viewBox="0 0 24 24"\n',
#        '       width="24px">\n',
#        '    <path d="M0 0h24v24H0V0z" fill="none"/>\n',
#        '    <path d="M18.56 5.44l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94zm-11 1L8.5 8.5l.94-2.06 2.06-.94-2.06-.94L8.5 2.5l-.94 2.06-2.06.94zm10 10l.94 2.06.94-2.06 2.06-.94-2.06-.94-.94-2.06-.94 2.06-2.06.94z"/><path d="M17.41 7.96l-1.37-1.37c-.4-.4-.92-.59-1.43-.59-.52 0-1.04.2-1.43.59L10.3 9.45l-7.72 7.72c-.78.78-.78 2.05 0 2.83L4 21.41c.39.39.9.59 1.41.59.51 0 1.02-.2 1.41-.59l7.78-7.78 2.81-2.81c.8-.78.8-2.07 0-2.86zM5.41 20L4 18.59l7.72-7.72 1.47 1.35L5.41 20z"/>\n',
#        '  </svg>\n',
#        '      </button>\n',
#        '      \n',
#        '  <style>\n',
#        '    .colab-df-container {\n',
#        '      display:flex;\n',
#        '      flex-wrap:wrap;\n',
#        '      gap: 12px;\n',
#        '    }\n',
#        '\n',
#        '    .colab-df-convert {\n',
#        '      background-color: #E8F0FE;\n',
#        '      border: none;\n',
#        '      border-radius: 50%;\n',
#        '      cursor: pointer;\n',
#        '      display: none;\n',
#        '      fill: #1967D2;\n',
#        '      height: 32px;\n',
#        '      padding: 0 0 0 0;\n',
#        '      width: 32px;\n',
#        '    }\n',
#        '\n',
#        '    .colab-df-convert:hover {\n',
#        '      background-color: #E2EBFA;\n',
#        '      box-shadow: 0px 1px 2px rgba(60, 64, 67, 0.3), 0px 1px 3px 1px rgba(60, 64, 67, 0.15);\n',
#        '      fill: #174EA6;\n',
#        '    }\n',
#        '\n',
#        '    [theme=dark] .colab-df-convert {\n',
#        '      background-color: #3B4455;\n',
#        '      fill: #D2E3FC;\n',
#        '    }\n',
#        '\n',
#        '    [theme=dark] .colab-df-convert:hover {\n',
#        '      background-color: #434B5C;\n',
#        '      box-shadow: 0px 1px 3px 1px rgba(0, 0, 0, 0.15);\n',
#        '      filter: drop-shadow(0px 1px 2px rgba(0, 0, 0, 0.3));\n',
#        '      fill: #FFFFFF;\n',
#        '    }\n',
#        '  </style>\n',
#        '\n',
#        '      <script>\n',
#        '        const buttonEl =\n',
#        "          document.querySelector('#df-6eb12a06-e931-43a7-bd6d-968ca7d06ed0 button.colab-df-convert');\n",
#        '        buttonEl.style.display =\n',
#        "          google.colab.kernel.accessAllowed ? 'block' : 'none';\n",
#        '\n',
#        '        async function convertToInteractive(key) {\n',
#        "          const element = document.querySelector('#df-6eb12a06-e931-43a7-bd6d-968ca7d06ed0');\n",
#        '          const dataTable =\n',
#        "            await google.colab.kernel.invokeFunction('convertToInteractive',\n",
#        '                                                     [key], {});\n',
#        '          if (!dataTable) return;\n',
#        '\n',
#        "          const docLinkHtml = 'Like what you see? Visit the ' +\n",
#        '            \'<a target="_blank" href=https://colab.research.google.com/notebooks/data_table.ipynb>data table notebook</a>\'\n',
#        "            + ' to learn more about interactive tables.';\n",
#        "          element.innerHTML = '';\n",
#        "          dataTable['output_type'] = 'display_data';\n",
#        '          await google.colab.output.renderOutput(dataTable, element);\n',
#        "          const docLink = document.createElement('div');\n",
#        '          docLink.innerHTML = docLinkHtml;\n',
#        '          element.appendChild(docLink);\n',
#        '        }\n',
#        '      </script>\n',
#        '    </div>\n',
#        '  </div>\n',
#        '  ']},
#      'metadata': {},
#      'execution_count': 16}]},
#   {'cell_type': 'code',
#    'source': ['#univariate analysis for Numerical datatypes\n',
#     "df.select_dtypes(include=['int64','float64','Int64']).dtypes"],
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/'},
#     'id': 'ZdINrezEHmZB',
#     'outputId': '662dc7a0-3692-4131-800d-4fe7094c4d5a'},
#    'execution_count': 42,
#    'outputs': [{'output_type': 'execute_result',
#      'data': {'text/plain': ['RowNumber            int64\n',
#        'CustomerId           int64\n',
#        'CreditScore          int64\n',
#        'Age                  int64\n',
#        'Tenure               int64\n',
#        'Balance            float64\n',
#        'NumOfProducts        int64\n',
#        'HasCrCard            int64\n',
#        'IsActiveMember       int64\n',
#        'EstimatedSalary    float64\n',
#        'Exited               int64\n',
#        'dtype: object']},
#      'metadata': {},
#      'execution_count': 42}]},
#   {'cell_type': 'code',
#    'source': ['# seggregating variables into groups\n',
#     "customer_details = ['CustomerId','Age','Tenure','CreditScore']\n",
#     "employee = ['Balance','NumOfProducts','HasCrCard', 'IsActiveMember','EstimatedSalary','Exited']\n"],
#    'metadata': {'id': 'E9cnRFBHIcGt'},
#    'execution_count': 40,
#    'outputs': []},
#   {'cell_type': 'code',
#    'source': ['def UVA_numeric(df, var_group):\n',
#     "  '''\n",
#     '  Univariate_Analysis_numeric\n',
#     '  takes a group of variables (INTEGER and FLOAT) and plot/print all the descriptives and properties along with KDE.\n',
#     '\n',
#     '  Runs a loop: calculate all the descriptives of i(th) variable and plot/print it\n',
#     "  '''\n",
#     '\n',
#     '  size = len(var_group)\n',
#     '  plt.figure(figsize = (7*size,3), dpi = 100)\n',
#     '  \n',
#     '  #looping for each variable\n',
#     '  for j,i in enumerate(var_group):\n',
#     '    \n',
#     '    # calculating descriptives of variable\n',
#     '    mini = df[i].min()\n',
#     '    maxi = df[i].max()\n',
#     '    ran =  df[i].max()-df[i].min()\n',
#     '    mean = df[i].mean()\n',
#     '    median =df[i].median()\n',
#     '    st_dev = df[i].std()\n',
#     '    skew = df[i].skew()\n',
#     '    kurt = df[i].kurtosis()\n',
#     '\n',
#     '    # calculating points of standard deviation\n',
#     '    points = mean-st_dev, mean+st_dev\n',
#     '\n',
#     '    #Plotting the variable with every information\n',
#     '    plt.subplot(1,size,j+1)\n',
#     '    sns.kdeplot(df[i], shade=True)\n',
#     '    sns.lineplot(points, [0,0], color = \'black\', label = "std_dev")\n',
#     '    sns.scatterplot([mini,maxi], [0,0], color = \'orange\', label = "min/max")\n',
#     '    sns.scatterplot([mean], [0], color = \'red\', label = "mean")\n',
#     '    sns.scatterplot([median], [0], color = \'blue\', label = "median")\n',
#     "    plt.xlabel('{}'.format(i), fontsize = 20)\n",
#     "    plt.ylabel('density')\n",
#     "    plt.title('std_dev = {}; kurtosis = {};\\nskew = {}; range = {}\\nmean = {}; median = {}'.format((round(points[0],2),round(points[1],2)),\n",
#     '    round(kurt,2),\n',
#     '    round(skew,2),\n',
#     '    (round(mini,2), round(maxi,2),round(ran,2)),\n',
#     '    round(mean,2),\n',
#     '    round(median,2)))                                                                                                                                                                         \n',
#     '                                                                                                   '],
#    'metadata': {'id': 'zZiiX_BvMW24'},
#    'execution_count': 30,
#    'outputs': []},
#   {'cell_type': 'code',
# ...
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n']},
#     {'output_type': 'display_data',
#      'data': {'text/plain': ['<Figure size 4200x300 with 6 Axes>'],
#       'image/png': '...\n'},
#      'metadata': {'needs_background': 'light'}}]},
#   {'cell_type': 'code',
#    'source': ['UVA_numeric(df,customer_details)'],
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/',
#      'height': 959},
#     'id': 'xiwuiomoSJqf',
#     'outputId': '81422cda-9da8-4cd2-df54-0907d15f3218'},
#    'execution_count': 41,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': ['/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n']},
#     {'output_type': 'display_data',
#      'data': {'text/plain': ['<Figure size 2800x300 with 4 Axes>'],
#       'image/png': '...\n'},
#      'metadata': {'needs_background': 'light'}}]},
#   {'cell_type': 'code',
#    'source': ['# custom function for easy outlier analysis\n',
#     '\n',
#     'def UVA_outlier(df, var_group, include_outlier = True):\n',
#     "  '''\n",
#     '  Univariate_Analysis_outlier:\n',
#     '  takes a group of variables (INTEGER and FLOAT) and plot/print boplot and descriptives\\n\n',
#     '  Runs a loop: calculate all the descriptives of i(th) variable and plot/print it \\n\\n\n',
#     '\n',
#     '  data : dataframe from which to plot from\\n\n',
#     '  var_group : {list} type Group of Continuous variables\\n\n',
#     '  include_outlier : {bool} whether to include outliers or not, default = True\\n\n',
#     "  '''\n",
#     '  size = len(var_group)\n',
#     '  plt.figure(figsize = (7*size,4), dpi = 100)\n',
#     '  \n',
#     '  #looping for each variable\n',
#     '  for j,i in enumerate(var_group):\n',
#     '    \n',
#     '    # calculating descriptives of variable\n',
#     '    quant25 = df[i].quantile(0.25)\n',
#     '    quant75 = df[i].quantile(0.75)\n',
#     '    IQR = quant75 - quant25\n',
#     '    med = df[i].median()\n',
#     '    whis_low = quant25-(1.5*IQR)\n',
#     '    whis_high = quant75+(1.5*IQR)\n',
#     '     # Calculating Number of Outliers\n',
#     '    outlier_high = len(df[i][df[i]>whis_high])\n',
#     '    outlier_low = len(df[i][df[i]<whis_low])\n',
#     '\n',
#     '    if include_outlier == True:\n',
#     '      #Plotting the variable with every information\n',
#     '      plt.subplot(1,size,j+1)\n',
#     '      sns.boxplot(df[i], orient="v")\n',
#     "      plt.ylabel('{}'.format(i))\n",
#     "      plt.title('With Outliers\\nIQR = {}; Median = {} \\n 2nd,3rd  quartile = {};\\n Outlier (low/high) = {} \\n'.format(\n",
#     '          \n',
#     'round(IQR,2),\n',
#     'round(med,2),\n',
#     '(round(quant25,2),round(quant75,2)),\n',
#     '(outlier_low,outlier_high)\n',
#     '))\n',
#     '    else:\n',
#     '      # replacing outliers with max/min whisker\n',
#     '      df2 = df[var_group][:]\n',
#     '      df2[i][df2[i]>whis_high] = whis_high+1\n',
#     '      df2[i][df2[i]<whis_low] = whis_low-1\n',
#     '      \n',
#     '      # plotting without outliers\n',
#     '      plt.subplot(1,size,j+1)\n',
#     '      sns.boxplot(df2[i], orient="v")\n',
#     "      plt.ylabel('{}'.format(i))\n",
#     "      plt.title('Without Outliers\\nIQR = {}; Median = {} \\n 2nd,3rd  quartile = {};\\n Outlier (low/high) = {} \\n'.format(\n",
#     '      round(IQR,2), \n',
#     '      round(med,2),\n',
#     '      (round(quant25,2),round(quant75,2)) \n',
#     '      (outlier_low,outlier_high)\n',
#     '      )) \n',
#     '                                                                                                   '],
#    'metadata': {'id': 'PteH2skSTMwg'},
#    'execution_count': 44,
#    'outputs': []},
#   {'cell_type': 'code',
#    'source': ['UVA_outlier(df, customer_details)'],
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/',
#      'height': 785},
#     'id': 'yH_7HUd6VUtI',
#     'outputId': 'd92d9eba-45d2-4764-ce12-ad5066f7f7e2'},
#    'execution_count': 46,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': ['/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n',
#       '  warnings.warn(single_var_warning.format("Vertical", "x"))\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n',
#       '  warnings.warn(single_var_warning.format("Vertical", "x"))\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n',
#       '  warnings.warn(single_var_warning.format("Vertical", "x"))\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n',
#       '  warnings.warn(single_var_warning.format("Vertical", "x"))\n']},
#     {'output_type': 'display_data',
#      'data': {'text/plain': ['<Figure size 2800x400 with 4 Axes>'],
#       'image/png': '...\n'},
#      'metadata': {'needs_background': 'light'}}]},
#   {'cell_type': 'code',
#    'source': ['UVA_outlier(df, customer_details, include_outlier= False)'],
#    'metadata': {'colab': {'base_uri': 'https://localhost:8080/',
#      'height': 785},
#     'id': 'CB2ADxUXZUub',
#     'outputId': '43cf853c-c701-41a5-b8e8-218e09198af0'},
#    'execution_count': 62,
#    'outputs': [{'output_type': 'stream',
#      'name': 'stderr',
#      'text': ['/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n',
#       '  warnings.warn(single_var_warning.format("Vertical", "x"))\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n',
#       '  warnings.warn(single_var_warning.format("Vertical", "x"))\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n',
#       '  warnings.warn(single_var_warning.format("Vertical", "x"))\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n',
#       '  FutureWarning\n',
#       '/usr/local/lib/python3.7/dist-packages/seaborn/_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.\n',
#       '  warnings.warn(single_var_warning.format("Vertical", "x"))\n']},
#     {'output_type': 'display_data',
#      'data': {'text/plain': ['<Figure size 2800x400 with 4 Axes>'],
#       'image/png': '...\n'},
#      'metadata': {'needs_background': 'light'}}]}]}
